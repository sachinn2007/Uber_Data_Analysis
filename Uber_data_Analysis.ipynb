# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Uber_Dataset.csv")

# %%
dataset
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   str
#  1   END_DATE    1155 non-null   str
#  2   CATEGORY    1155 non-null   str
#  3   START       1155 non-null   str
#  4   STOP        1155 non-null   str
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    str
# dtypes: float64(1), str(6)
# memory usage: 137.1 KB

# %% [markdown]
# # Data Preprocessing

# %%
dataset["PURPOSE"] = dataset["PURPOSE"].fillna("NOT", inplace = True)
# Out:
# C:\Users\SACHIN\AppData\Local\Temp\ipykernel_11012\2546146211.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   dataset["PURPOSE"] = dataset["PURPOSE"].fillna("NOT", inplace = True)

# %%
dataset.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
dataset["START_DATE"] = pd.to_datetime(dataset["START_DATE"], errors = "coerce")
dataset["END_DATE"] = pd.to_datetime(dataset["END_DATE"], errors = "coerce")

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE
# 0      Fort Pierce    5.1   Meal/Entertain
# 1      Fort Pierce    5.0              NOT
# 2      Fort Pierce    4.8  Errand/Supplies
# 3      Fort Pierce    4.7          Meeting
# 4  West Palm Beach   63.7   Customer Visit

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[us]
#  1   END_DATE    420 non-null    datetime64[us]
#  2   CATEGORY    1155 non-null   str
#  3   START       1155 non-null   str
#  4   STOP        1155 non-null   str
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   str
# dtypes: datetime64[us](2), float64(1), str(4)
# memory usage: 103.3 KB

# %%
from datetime import datetime

dataset["DATE"] = pd.DatetimeIndex(dataset["START_DATE"]).date

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01
# 1      Fort Pierce    5.0              NOT  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06

# %%
from datetime import datetime

dataset["TIME"] = pd.DatetimeIndex(dataset["START_DATE"]).hour

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
dataset["DAY_NIGHT"] = pd.cut(x = dataset["TIME"],
bins = [0,10,15,19,24],
labels = ["Morning", "Afternoon", "Evening", "Night"])

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
dataset.dropna(inplace = True)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
dataset.shape
# Out:
# (413, 10)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # 1. In which category do people book the most Uber rides?

# %%
plt.figure(figsize = (20,6))
plt.subplot(1,2,1)
sns.countplot(x = dataset["CATEGORY"],width=0.3)
plt.title("MOST BOOKED CATEGORY")
plt.ylabel("COUNT")
plt.xlabel("CATEGORY")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. For which purpose do people book Uber rides the most?

# %%
plt.figure(figsize = (20,8))
plt.subplot(1,2,2)
sns.countplot(x = dataset["PURPOSE"],width = 0.6)
plt.ylabel("COUNT")
plt.xticks(rotation = 40,fontsize = 10)
plt.title("PRIMARY PURPOSE OF RIDES")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. At what time do people book cabs the most from Uber?

# %%
sns.countplot(x = dataset["DAY_NIGHT"], width = 0.4)
plt.ylabel("COUNT")
plt.title("PEAK BOOKING TIME")
plt.tight_layout()
plt.show()

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
dataset["MONTH"] = pd.DatetimeIndex(dataset["START_DATE"]).month
month_label = {1.0:"Jan",
               2.0: "Feb",
               3.0: "Mar",
               4.0: "April",
                5.0: "May",
               6.0: "June",
               7.0: "July", 
               8.0: "Aug",
                9.0: "Sep",
               10.0: "Oct", 
               11.0: "Nov",
               12.0: "Dec"}
dataset["MONTH"] = dataset.MONTH.map(month_label)
mon = dataset.MONTH.value_counts(sort = False)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT MONTH
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night   Jan
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning   Jan
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night   Jan
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening   Jan
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon   Jan

# %% [markdown]
# # 4. In which months do people book Uber rides less frequently?

# %%
df = pd.DataFrame({
    "MONTHS": mon.values, 
    "VALUE COUNT": dataset.groupby('MONTH', sort=False)['MILES'].max() 
})

p = sns.lineplot(data=df)  
p.set(xlabel="MONTHS", ylabel="VALUE COUNT")
plt.title("LOW DEMAND MONTHS")
plt.tight_layout()
plt.show()

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT MONTH
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night   Jan
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning   Jan
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night   Jan
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening   Jan
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon   Jan

# %%
dataset["DAY"] = dataset.START_DATE.dt.weekday
day_label = {
    0: "Mon",
    1: "Tues",
    2: "Web",
    3: "Thur",
    4: "Fri",
    5: "Sat",
    6: "sun"
}
dataset["DAY"] = dataset["DAY"].map(day_label)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT MONTH  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night   Jan
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning   Jan
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night   Jan
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening   Jan
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon   Jan
#
#     DAY
# 0   Fri
# 1   Sat
# 2   Sat
# 3  Tues
# 4   Web

# %% [markdown]
# # 5. On which days of the week do people book Uber rides the most?

# %%
day_label = dataset.DAY.value_counts()
sns.barplot(x = day_label.index, y = day_label)
plt.title("BUSIEST DAYS OF THE WEEK")
plt.tight_layout()
plt.xlabel("DAY")
plt.ylabel("COUNT")
plt.show()

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        DATE  TIME  DAY_NIGHT MONTH  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night   Jan
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning   Jan
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night   Jan
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening   Jan
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon   Jan
#
#     DAY
# 0   Fri
# 1   Sat
# 2   Sat
# 3  Tues
# 4   Web

# %% [markdown]
# # 6. How many miles do people usually book a cab for through Uber?

# %%
sns.boxplot(dataset["MILES"])
plt.title("TYPICAL TRIP DISTANCE")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dataset[dataset["MILES"]<100]["MILES"])
plt.title("TYPICAL TRIP DISTANCE")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dataset[dataset["MILES"]<40]["MILES"])
plt.title("TYPICAL TRIP DISTANCE")
plt.tight_layout()
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Uber is primarily used for business purposes, especially meetings and meals/entertainment.
# Demand peaks in the afternoon, is strongest toward the end of the work week (Thursday–Friday), and drops in winter months (Nov–Jan).
# Most trips are short-distance (around 4–5 miles, almost all under 20 miles).
# These patterns suggest Uber is heavily used by professionals for work-related short trips during business hours.
